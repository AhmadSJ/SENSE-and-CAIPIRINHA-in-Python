# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat

# %%
x = loadmat('pos1_epi80.mat')
x.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'csm_img', 'sense_img'])

# %%
ksp = x['sense_img']
csm = x['csm_img']

# %%
print(ksp.shape, csm.shape)
# Out:
# (68, 240, 32, 32) (33, 113, 32, 32)

# %%
plt.imshow(abs(ksp[:,:,5,10]),cmap='gray')

# %%
plt.imshow(abs(csm[:,:,5,10]),cmap='gray')

# %%
s = np.fft.ifft(csm[:,:,5,10])

# %%
plt.imshow(abs(s))
